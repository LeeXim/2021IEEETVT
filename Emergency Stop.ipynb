# %%
import matplotlib
from matplotlib import pyplot as plt
import pickle
from collections import defaultdict

# %%
file = open("./TD3300202109011806482904",'rb')

# %%
velodict = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-51-6c83ca7a800f> in <module>
# ----> 1 velodict = pickle.load(f)
#
# EOFError: Ran out of input

# %%
velodict
# Out:
# "defaultdict(<class 'list'>, {'outline_0': [1.998082223672191, 1.9943673027041724, 1.9840483980853916, 1.979195907357113, 1.969337036440867, 1.9797480224542376, 1.9859912827229032, 2.0011870803156175, 2.005428128686701, 2.0077506272802004, 2.0054629327261115, 2.009011439099872, 1.9953503267619552, 2.003021092740189, 2.262399886330724, 2.5214628355269397, 2.374838831418502, 2.2782402603019074, 2.2036004531683497, 2.1496708466103045, 2.113745989411021, 2.095326713033894, 2.071149404723996, 2.0517612938528145, 2.045146819567506, 2.0435173060017635, 2.0364185175579244, 2.0218721639561292, 2.007309805569697, 2.003586773911768, 2.0140528451325346, 2.012174092047812, 2.0188703620911146, 2.012739026938193, 2.0045830299849894, 1.9986688112860977, 1.996331345217214, 1.99617167071764, 2.0112150378934057, 2.0090678473695625, 2.0112781887184776, 2.0026910776780764, 1.997995852842646, 1.99936834969609, 1.9863128676912625, 1.9878244377121563, 1.9869874034399364, 1.9874927411010728, 1.98529479269894
# ...

# %%
veh = list(velodict.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-4128fbb378c2> in <module>
# ----> 1 veh = list(velodict.keys())
#
# AttributeError: 'str' object has no attribute 'keys'
